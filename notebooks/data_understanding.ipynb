# %%
import pandas as pd

df = pd.read_csv("../data/train.csv")

df.head()
# Out:
#    Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0        1048   22  Female  B.Tech    ECE  6.29            0         3
# 1       37820   20  Female     BCA    ECE  6.05            1         4
# 2       49668   22    Male     MCA     ME  7.22            1         4
# 3       19467   22    Male     MCA     ME  7.78            2         4
# 4       23094   20  Female  B.Tech     ME  7.63            1         4
#
#    Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0              4                     6                   51
# 1              6                     8                   59
# 2              6                     6                   58
# 3              6                     6                   90
# 4              6                     5                   79
#
#    Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 0                   5               1         3       Not Placed
# ...

# %% [markdown]
# # Data Understanding
#
# ### Summary
#
# - Dataset contains 45000 records and 15 columns.
# - No missing values
# - No duplicate records.
# - Categorical columns are consistent.
# - Numerical values fall within realistic ranges.
# - Student_ID is an identifier and has to be dropped.
# - Target variable is Placement_Status.

# %%
# Dataset shape
df.shape
# Out:
# (45000, 15)

# %%
# Dataset Information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            45000 non-null  int64
#  1   Age                   45000 non-null  int64
#  2   Gender                45000 non-null  str
#  3   Degree                45000 non-null  str
#  4   Branch                45000 non-null  str
#  5   CGPA                  45000 non-null  float64
#  6   Internships           45000 non-null  int64
#  7   Projects              45000 non-null  int64
#  8   Coding_Skills         45000 non-null  int64
#  9   Communication_Skills  45000 non-null  int64
#  10  Aptitude_Test_Score   45000 non-null  int64
#  11  Soft_Skills_Rating    45000 non-null  int64
#  12  Certifications        45000 non-null  int64
#  13  Backlogs              45000 non-null  int64
#  14  Placement_Status      45000 non-null  str
# ...

# %%
# Dataset columns
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Degree', 'Branch', 'CGPA',
#        'Internships', 'Projects', 'Coding_Skills', 'Communication_Skills',
#        'Aptitude_Test_Score', 'Soft_Skills_Rating', 'Certifications',
#        'Backlogs', 'Placement_Status'],
#       dtype='str')

# %%
# Placement status
df["Placement_Status"].value_counts()
# Out:
# Placement_Status
# Not Placed    28688
# Placed        16312
# Name: count, dtype: int64

# %%
# Age
df["Age"].describe()
# Out:
# count    45000.000000
# mean        20.999333
# std          1.995071
# min         18.000000
# 25%         19.000000
# 50%         21.000000
# 75%         23.000000
# max         24.000000
# Name: Age, dtype: float64

# %%
# Gender
df["Gender"].value_counts()
# Out:
# Gender
# Female    22620
# Male      22380
# Name: count, dtype: int64

# %%
# Degree
df["Degree"].value_counts()
# Out:
# Degree
# B.Sc      11357
# B.Tech    11305
# MCA       11289
# BCA       11049
# Name: count, dtype: int64

# %%
# Branch
df["Branch"].value_counts()
# Out:
# Branch
# ME       9056
# ECE      9026
# CSE      8989
# Civil    8981
# IT       8948
# Name: count, dtype: int64

# %%
# CGPA
df["CGPA"].describe()
# Out:
# count    45000.000000
# mean         7.002290
# std          0.993855
# min          4.500000
# 25%          6.320000
# 50%          7.000000
# 75%          7.670000
# max          9.800000
# Name: CGPA, dtype: float64

# %%
# Internships
df["Internships"].describe()
# Out:
# count    45000.000000
# mean         0.774089
# std          0.844750
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: Internships, dtype: float64

# %%
# Projects
df["Projects"].describe()
# Out:
# count    45000.000000
# mean         3.734222
# std          0.923738
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          4.000000
# max          6.000000
# Name: Projects, dtype: float64

# %%
# Coding Skills
df["Coding_Skills"].describe()
# Out:
# count    45000.000000
# mean         5.691800
# std          1.994674
# min          1.000000
# 25%          4.000000
# 50%          6.000000
# 75%          7.000000
# max         10.000000
# Name: Coding_Skills, dtype: float64

# %%
# Communication skills
df["Communication_Skills"].describe()
# Out:
# count    45000.000000
# mean         5.501644
# std          1.515374
# min          1.000000
# 25%          4.000000
# 50%          6.000000
# 75%          7.000000
# max         10.000000
# Name: Communication_Skills, dtype: float64

# %%
# Aptitude Test Score
df["Aptitude_Test_Score"].describe()
# Out:
# count    45000.000000
# mean        69.385356
# std         13.909710
# min         35.000000
# 25%         60.000000
# 50%         69.000000
# 75%         79.000000
# max        100.000000
# Name: Aptitude_Test_Score, dtype: float64

# %%
# Soft Skills Rating
df["Soft_Skills_Rating"].describe()
# Out:
# count    45000.000000
# mean         5.501644
# std          1.238722
# min          1.000000
# 25%          5.000000
# 50%          5.000000
# 75%          6.000000
# max         10.000000
# Name: Soft_Skills_Rating, dtype: float64

# %%
# Certifications
df["Certifications"].describe()
# Out:
# count    45000.000000
# mean         1.800956
# std          0.650104
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000
# Name: Certifications, dtype: float64

# %%
# Backlogs
df["Backlogs"].describe()
# Out:
# count    45000.000000
# mean         0.888133
# std          0.970954
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          3.000000
# Name: Backlogs, dtype: float64
